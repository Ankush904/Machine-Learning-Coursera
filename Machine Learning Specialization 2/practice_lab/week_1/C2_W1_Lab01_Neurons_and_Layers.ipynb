# %% [markdown]
# # Optional Lab - Neurons and Layers
# In this lab we will explore the inner workings of neurons/units and layers. In particular, the lab will draw parallels to the models you have mastered in Course 1, the regression/linear model and the logistic model. The lab will introduce Tensorflow and demonstrate how these models are implemented in that framework.
# <figure>
#    <img src="./images/C2_W1_NeuronsAndLayers.png"  style="width:540px;height:200px;" >
# </figure>

# %% [markdown]
# ## Packages
# **Tensorflow and Keras**
# Tensorflow is a machine learning package developed by Google. In 2019, Google integrated Keras into Tensorflow and released Tensorflow 2.0. Keras is a framework developed independently by François Chollet that creates a simple, layer-centric interface to Tensorflow. This course will be using the Keras interface.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import sigmoid
from lab_utils_common import dlc
from lab_neurons_utils import plt_prob_1d, sigmoidnp, plt_linear, plt_logistic
plt.style.use('./deeplearning.mplstyle')
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# ## Neuron without activation - Regression/Linear Model

# %% [markdown]
# ### DataSet
# We'll use an example from Course 1, linear regression on house prices.

# %%
X_train = np.array([[1.0], [2.0]], dtype=np.float32)           #(size in 1000 square feet)
Y_train = np.array([[300.0], [500.0]], dtype=np.float32)       #(price in 1000s of dollars)

fig, ax = plt.subplots(1,1)
ax.scatter(X_train, Y_train, marker='x', c='r', label="Data Points")
ax.legend( fontsize='xx-large')
ax.set_ylabel('Price (in 1000s of dollars)', fontsize='xx-large')
ax.set_xlabel('Size (1000 sqft)', fontsize='xx-large')
plt.show()

# %% [markdown]
# ### Regression/Linear Model
# The function implemented by a neuron with no activation is the same as in Course 1, linear regression:
# $$ f_{\mathbf{w},b}(x^{(i)}) = \mathbf{w}\cdot x^{(i)} + b \tag{1}$$

# %% [markdown]
# We can define a layer with one neuron or unit and compare it to the familiar linear regression function.

# %%
linear_layer = tf.keras.layers.Dense(units=1, activation = 'linear', )

# %% [markdown]
# Let's examine the weights.

# %%
linear_layer.get_weights()
# Out:
# []

# %% [markdown]
# There are no weights as the weights are not yet instantiated. Let's try the model on one example in `X_train`. This will trigger the instantiation of the weights. Note, the input to the layer must be 2-D, so we'll reshape it.

# %%
a1 = linear_layer(X_train[0].reshape(1,1))
print(a1)
# Out:
# tf.Tensor([[-0.07]], shape=(1, 1), dtype=float32)

# %% [markdown]
# The result is a tensor (another name for an array) with a shape of (1,1) or one entry.
# Now let's look at the weights and bias. These weights are randomly initialized to small numbers and the bias defaults to being initialized to zero.

# %%
w, b= linear_layer.get_weights()
print(f"w = {w}, b={b}")
# Out:
# w = [[-0.07]], b=[0.]

# %% [markdown]
# A linear regression model (1) with a single input feature will have a single weight and bias. This matches the dimensions of our `linear_layer` above.
#
# The weights are initialized to random values so let's set them to some known values.

# %%
set_w = np.array([[200]])
set_b = np.array([100])

# set_weights takes a list of numpy arrays
linear_layer.set_weights([set_w, set_b])
print(linear_layer.get_weights())
# Out:
# [array([[200.]], dtype=float32), array([100.], dtype=float32)]

# %% [markdown]
# Let's compare equation (1) to the layer output.

# %%
a1 = linear_layer(X_train[0].reshape(1,1))
print(a1)
alin = np.dot(set_w,X_train[0].reshape(1,1)) + set_b
print(alin)
# Out:
# tf.Tensor([[300.]], shape=(1, 1), dtype=float32)
# [[300.]]

# %% [markdown]
# They produce the same values!
# Now, we can use our linear layer to make predictions on our training data.

# %%
prediction_tf = linear_layer(X_train)
prediction_np = np.dot( X_train, set_w) + set_b

# %%
plt_linear(X_train, Y_train, prediction_tf, prediction_np)

# %% [markdown]
# ### Different Method

# %%
from keras import backend as k

# %%
# Root mean Square Error
def rmse(y_true,y_pred):
    return k.sqrt(k.mean(y_pred -y_true))

# %%
model = Sequential([
    Dense(100, activation = 'relu'),
    Dense(100, activation = 'relu'),
    Dense(100, activation = 'relu'),
    Dense(1)
])

model.compile(optimizer= tf.keras.optimizers.Adam(0.0492), loss='mean_squared_error')

model.fit(X_train,Y_train,epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 991ms/step - loss: 170125.4375
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 167128.3750
# Epoch 3/100
# 1/1 [==============================] - 0s 8ms/step - loss: 156927.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 16ms/step - loss: 132845.8438
# Epoch 5/100
# 1/1 [==============================] - 0s 10ms/step - loss: 89229.2891
# Epoch 6/100
# 1/1 [==============================] - 0s 15ms/step - loss: 30813.8535
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1969.1648
# Epoch 8/100
# 1/1 [==============================] - 0s 16ms/step - loss: 71318.5156
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 33474.4180
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2040.4927
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4857.5371
# Epoch 12/100
# 1/1 [==============================] - 0s 8ms/step - loss: 19232.0293
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 29538.0664
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 31989.7422
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 27179.3828
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 17286.0000
# Epoch 17/100
# 1/1 [==============================] - 0s 16ms/step - loss: 6256.2656
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 181.2601
# Epoch 19/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4187.6284
# Epoch 20/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13723.0957
# Epoch 21/100
# 1/1 [==============================] - 0s 8ms/step - loss: 15500.3730
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7882.2920
# Epoch 23/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1112.1058
# Epoch 24/100
# 1/1 [==============================] - 0s 10ms/step - loss: 585.3475
# Epoch 25/100
# 1/1 [==============================] - 0s 10ms/step - loss: 4026.0364
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7421.8496
# Epoch 27/100
# 1/1 [==============================] - 0s 6ms/step - loss: 8444.3203
# Epoch 28/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6741.1997
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3445.6218
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 641.0043
# Epoch 31/100
# 1/1 [==============================] - 0s 16ms/step - loss: 305.3197
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2468.5371
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4458.9956
# Epoch 34/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3832.7812
# Epoch 35/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1537.4417
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 122.1783
# Epoch 37/100
# 1/1 [==============================] - 0s 8ms/step - loss: 500.3037
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1719.9431
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2482.6392
# Epoch 40/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2191.4424
# Epoch 41/100
# 1/1 [==============================] - 0s 9ms/step - loss: 1146.5465
# Epoch 42/100
# 1/1 [==============================] - 0s 9ms/step - loss: 214.9100
# Epoch 43/100
# 1/1 [==============================] - 0s 8ms/step - loss: 148.5245
# Epoch 44/100
# 1/1 [==============================] - 0s 6ms/step - loss: 853.3386
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1403.1838
# Epoch 46/100
# 1/1 [==============================] - 0s 14ms/step - loss: 1127.3013
# Epoch 47/100
# 1/1 [==============================] - 0s 8ms/step - loss: 408.9523
# Epoch 48/100
# 1/1 [==============================] - 0s 16ms/step - loss: 42.9617
# Epoch 49/100
# 1/1 [==============================] - 0s 8ms/step - loss: 260.3791
# Epoch 50/100
# 1/1 [==============================] - 0s 8ms/step - loss: 668.0227
# Epoch 51/100
# 1/1 [==============================] - 0s 8ms/step - loss: 801.1791
# Epoch 52/100
# 1/1 [==============================] - 0s 8ms/step - loss: 546.8423
# Epoch 53/100
# 1/1 [==============================] - 0s 8ms/step - loss: 171.5315
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 34.0317
# Epoch 55/100
# 1/1 [==============================] - 0s 16ms/step - loss: 218.6579
# Epoch 56/100
# 1/1 [==============================] - 0s 8ms/step - loss: 445.3662
# Epoch 57/100
# 1/1 [==============================] - 0s 8ms/step - loss: 417.2673
# Epoch 58/100
# 1/1 [==============================] - 0s 16ms/step - loss: 184.7115
# Epoch 59/100
# 1/1 [==============================] - 0s 16ms/step - loss: 28.3809
# Epoch 60/100
# 1/1 [==============================] - 0s 10ms/step - loss: 83.7305
# Epoch 61/100
# 1/1 [==============================] - 0s 7ms/step - loss: 227.6168
# Epoch 62/100
# 1/1 [==============================] - 0s 6ms/step - loss: 272.7811
# Epoch 63/100
# 1/1 [==============================] - 0s 17ms/step - loss: 173.5802
# Epoch 64/100
# 1/1 [==============================] - 0s 9ms/step - loss: 46.5613
# Epoch 65/100
# 1/1 [==============================] - 0s 8ms/step - loss: 24.5725
# Epoch 66/100
# 1/1 [==============================] - 0s 8ms/step - loss: 105.1282
# Epoch 67/100
# 1/1 [==============================] - 0s 8ms/step - loss: 164.5575
# Epoch 68/100
# 1/1 [==============================] - 0s 16ms/step - loss: 123.3846
# Epoch 69/100
# 1/1 [==============================] - 0s 8ms/step - loss: 39.8697
# Epoch 70/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.4179
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 55.8766
# Epoch 72/100
# 1/1 [==============================] - 0s 8ms/step - loss: 96.9255
# Epoch 73/100
# 1/1 [==============================] - 0s 16ms/step - loss: 82.4214
# Epoch 74/100
# 1/1 [==============================] - 0s 8ms/step - loss: 33.0648
# Epoch 75/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.1270
# Epoch 76/100
# 1/1 [==============================] - 0s 8ms/step - loss: 29.0894
# Epoch 77/100
# 1/1 [==============================] - 0s 10ms/step - loss: 57.4327
# Epoch 78/100
# 1/1 [==============================] - 0s 6ms/step - loss: 51.4538
# Epoch 79/100
# 1/1 [==============================] - 0s 8ms/step - loss: 20.8538
# Epoch 80/100
# 1/1 [==============================] - 0s 16ms/step - loss: 5.4493
# Epoch 81/100
# 1/1 [==============================] - 0s 8ms/step - loss: 18.4337
# Epoch 82/100
# 1/1 [==============================] - 0s 8ms/step - loss: 35.0990
# Epoch 83/100
# 1/1 [==============================] - 0s 8ms/step - loss: 31.1252
# Epoch 84/100
# 1/1 [==============================] - 0s 8ms/step - loss: 12.6855
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 3.5366
# Epoch 86/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.8770
# Epoch 87/100
# 1/1 [==============================] - 0s 8ms/step - loss: 21.7785
# Epoch 88/100
# 1/1 [==============================] - 0s 16ms/step - loss: 17.9847
# Epoch 89/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3981
# Epoch 90/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.4474
# Epoch 91/100
# 1/1 [==============================] - 0s 8ms/step - loss: 8.6109
# Epoch 92/100
# 1/1 [==============================] - 0s 16ms/step - loss: 13.5891
# Epoch 93/100
# 1/1 [==============================] - 0s 8ms/step - loss: 9.8552
# Epoch 94/100
# 1/1 [==============================] - 0s 8ms/step - loss: 2.9570
# Epoch 95/100
# 1/1 [==============================] - 0s 7ms/step - loss: 1.8710
# Epoch 96/100
# 1/1 [==============================] - 0s 16ms/step - loss: 6.2280
# Epoch 97/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2654
# Epoch 98/100
# 1/1 [==============================] - 0s 11ms/step - loss: 4.8530
# Epoch 99/100
# 1/1 [==============================] - 0s 5ms/step - loss: 1.1087
# Epoch 100/100
# 1/1 [==============================] - 0s 8ms/step - loss: 1.7415

# %%
prediction = model.predict(X_train)
prediction
# Out:
# 1/1 [==============================] - 0s 308ms/step
# array([[299.52],
#        [497.03]], dtype=float32)

# %%
plt_linear(X_train, Y_train, prediction, prediction_np)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 100)               200
#
#  dense_2 (Dense)             (None, 100)               10100
#
#  dense_3 (Dense)             (None, 100)               10100
#
#  dense_4 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 20,501
# Trainable params: 20,501
# Non-trainable params: 0
# _________________________________________________________________

# %%
model1 = Sequential([
    Dense(100, activation = 'linear'),
    Dense(75, activation = 'linear'),
    Dense(50, activation = 'linear'),
    Dense(20, activation = 'linear'),
    Dense(1)
])

model1.compile(optimizer='adam',loss = 'mean_squared_error')

model1.fit(X_train,Y_train,epochs = 100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 926ms/step - loss: 169705.1562
# Epoch 2/100
# 1/1 [==============================] - 0s 9ms/step - loss: 169374.6875
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 169036.3750
# Epoch 4/100
# 1/1 [==============================] - 0s 6ms/step - loss: 168685.6406
# Epoch 5/100
# 1/1 [==============================] - 0s 8ms/step - loss: 168317.2500
# Epoch 6/100
# 1/1 [==============================] - 0s 16ms/step - loss: 167926.6875
# Epoch 7/100
# 1/1 [==============================] - 0s 8ms/step - loss: 167509.5938
# Epoch 8/100
# 1/1 [==============================] - 0s 8ms/step - loss: 167061.0469
# Epoch 9/100
# 1/1 [==============================] - 0s 16ms/step - loss: 166575.7031
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 166048.0312
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 165472.4062
# Epoch 12/100
# 1/1 [==============================] - 0s 16ms/step - loss: 164843.2344
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 164154.5625
# Epoch 14/100
# 1/1 [==============================] - 0s 8ms/step - loss: 163400.3750
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 162574.1094
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 161669.0312
# Epoch 17/100
# 1/1 [==============================] - 0s 16ms/step - loss: 160677.8750
# Epoch 18/100
# 1/1 [==============================] - 0s 16ms/step - loss: 159592.9375
# Epoch 19/100
# 1/1 [==============================] - 0s 16ms/step - loss: 158406.0156
# Epoch 20/100
# 1/1 [==============================] - 0s 6ms/step - loss: 157108.3281
# Epoch 21/100
# 1/1 [==============================] - 0s 8ms/step - loss: 155690.5625
# Epoch 22/100
# 1/1 [==============================] - 0s 8ms/step - loss: 154142.8438
# Epoch 23/100
# 1/1 [==============================] - 0s 8ms/step - loss: 152454.6875
# Epoch 24/100
# 1/1 [==============================] - 0s 8ms/step - loss: 150615.1875
# Epoch 25/100
# 1/1 [==============================] - 0s 8ms/step - loss: 148613.0312
# Epoch 26/100
# 1/1 [==============================] - 0s 8ms/step - loss: 146436.4375
# Epoch 27/100
# 1/1 [==============================] - 0s 8ms/step - loss: 144073.4688
# Epoch 28/100
# 1/1 [==============================] - 0s 8ms/step - loss: 141511.9688
# Epoch 29/100
# 1/1 [==============================] - 0s 8ms/step - loss: 138739.7969
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 135744.9844
# Epoch 31/100
# 1/1 [==============================] - 0s 8ms/step - loss: 132515.7969
# Epoch 32/100
# 1/1 [==============================] - 0s 8ms/step - loss: 129041.1172
# Epoch 33/100
# 1/1 [==============================] - 0s 8ms/step - loss: 125310.6172
# Epoch 34/100
# 1/1 [==============================] - 0s 16ms/step - loss: 121315.0391
# Epoch 35/100
# 1/1 [==============================] - 0s 10ms/step - loss: 117046.6875
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 112499.7734
# Epoch 37/100
# 1/1 [==============================] - 0s 6ms/step - loss: 107670.9219
# Epoch 38/100
# 1/1 [==============================] - 0s 8ms/step - loss: 102559.8125
# Epoch 39/100
# 1/1 [==============================] - 0s 8ms/step - loss: 97169.8203
# Epoch 40/100
# 1/1 [==============================] - 0s 16ms/step - loss: 91508.6953
# Epoch 41/100
# 1/1 [==============================] - 0s 8ms/step - loss:
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               200
#
#  dense_6 (Dense)             (None, 75)                7575
#
#  dense_7 (Dense)             (None, 50)                3800
#
#  dense_8 (Dense)             (None, 20)                1020
#
#  dense_9 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 12,616
# Trainable params: 12,616
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Neuron with Sigmoid activation
# The function implemented by a neuron/unit with a sigmoid activation is the same as in Course 1, logistic  regression:
# $$ f_{\mathbf{w},b}(x^{(i)}) = g(\mathbf{w}x^{(i)} + b) \tag{2}$$
# where $$g(x) = sigmoid(x)$$
#
# Let's set $w$ and $b$ to some known values and check the model.

# %% [markdown]
# ### DataSet
# We'll use an example from Course 1, logistic regression.

# %%
X_train = np.array([0., 1, 2, 3, 4, 5], dtype=np.float32).reshape(-1,1)  # 2-D Matrix
Y_train = np.array([0,  0, 0, 1, 1, 1], dtype=np.float32).reshape(-1,1)  # 2-D Matrix

# %%
pos = Y_train == 1
neg = Y_train == 0
X_train[pos]
# Out:
# array([3., 4., 5.], dtype=float32)

# %%
pos = Y_train == 1
neg = Y_train == 0

fig,ax = plt.subplots(1,1,figsize=(4,3))
ax.scatter(X_train[pos], Y_train[pos], marker='x', s=80, c = 'red', label="y=1")
ax.scatter(X_train[neg], Y_train[neg], marker='o', s=100, label="y=0", facecolors='none', 
              edgecolors=dlc["dlblue"],lw=3)

ax.set_ylim(-0.08,1.1)
ax.set_ylabel('y', fontsize=12)
ax.set_xlabel('x', fontsize=12)
ax.set_title('one variable plot')
ax.legend(fontsize=12)
plt.show()

# %% [markdown]
# ### Logistic Neuron
# We can implement a 'logistic neuron' by adding a sigmoid activation. The function of the neuron is then described by (2) above.
# This section will create a Tensorflow Model that contains our logistic layer to demonstrate an alternate method of creating models. Tensorflow is most often used to create multi-layer models. The [Sequential](https://keras.io/guides/sequential_model/) model is a convenient means of constructing these models.

# %%
model = Sequential(
    [
        tf.keras.layers.Dense(1, input_dim=1,  activation = 'sigmoid', name='L1')
    ]
)

# %% [markdown]
# `model.summary()` shows the layers and number of parameters in the model. There is only one layer in this model and that layer has only one unit. The unit has two parameters, $w$ and $b$.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  L1 (Dense)                  (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
logistic_layer = model.get_layer('L1')
w,b = logistic_layer.get_weights()
print(w,b)
print(w.shape,b.shape)
# Out:
# [[-1.41]] [0.]
# (1, 1) (1,)

# %% [markdown]
# Let's set the weight and bias to some known values.

# %%
set_w = np.array([[2]])
set_b = np.array([-4.5])
# set_weights takes a list of numpy arrays
logistic_layer.set_weights([set_w, set_b])
print(logistic_layer.get_weights())
# Out:
# [array([[2.]], dtype=float32), array([-4.5], dtype=float32)]

# %% [markdown]
# Let's compare equation (2) to the layer output.

# %%
a1 = model.predict(X_train[0].reshape(1,1))
print(a1)
alog = sigmoidnp(np.dot(set_w,X_train[0].reshape(1,1)) + set_b)
print(alog)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# [[0.01]]
# [[0.01]]

# %% [markdown]
# They produce the same values!
# Now, we can use our logistic layer and NumPy model to make predictions on our training data.

# %%
plt_logistic(X_train, Y_train, model, set_w, set_b, pos, neg)
# Out:
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step

# %% [markdown]
# The shading above reflects the output of the sigmoid which varies from 0 to 1.

# %% [markdown]
# # Congratulations!
# You built a very simple neural network and have explored the similarities of a neuron to the linear and logistic regression from Course 1.
